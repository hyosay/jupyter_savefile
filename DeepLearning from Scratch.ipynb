# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('/Users/jeonhyoseong/Desktop/스크린샷 2021-04-10 오후 11.16.11.png')
plt.imshow(img)
plt.show()

# %%
import numpy as np
x = np.random.rand(100)
y = x
plt.plot(x, y, label='$xx$',color = 'black')
plt.title('x')
plt.xlabel("$x$")
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
ㅛ
# Out:
# a
# b
